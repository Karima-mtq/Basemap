# %% [markdown]
# <a href="https://colab.research.google.com/github/Karima-mtq/Basemap/blob/main/EOF_SST_NudA-UVT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install netCDF4
# !pip install eofs
# !pip install Basemap
# Out:
# Requirement already satisfied: netCDF4 in /usr/local/lib/python3.12/dist-packages (1.7.3)
# Requirement already satisfied: cftime in /usr/local/lib/python3.12/dist-packages (from netCDF4) (1.6.5)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from netCDF4) (2025.10.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from netCDF4) (2.0.2)
# Requirement already satisfied: eofs in /usr/local/lib/python3.12/dist-packages (2.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from eofs) (2.0.2)
# Requirement already satisfied: Basemap in /usr/local/lib/python3.12/dist-packages (2.0.0)
# Requirement already satisfied: basemap_data<3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from Basemap) (2.0.0)
# Requirement already satisfied: packaging<26.0,>=20.5 in /usr/local/lib/python3.12/dist-packages (from Basemap) (25.0)
# Requirement already satisfied: numpy<2.4,>=2.0 in /usr/local/lib/python3.12/dist-packages (from Basemap) (2.0.2)
# Requirement already satisfied: matplotlib<3.11,>=3.4 in /usr/local/lib/python3.12/dist-packages (from Basemap) (3.10.0)
# Requirement already satisfied: pyproj<3.8,>=3.0 in /usr/local/lib/python3.12/dist-packages (from Basemap) (3.7.2)
# Requirement already satisfied: pyshp<2.4,>=2.0 in /usr/local/lib/python3.12/dist-packages (from Basemap) (2.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.4->Basemap) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.4->Basemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.4->Basemap) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.4->Basemap) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.4->Basemap) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.4->Basemap) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.4->Basemap) (2.9.0.post0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyproj<3.8,>=3.0->Basemap) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib<3.11,>=3.4->Basemap) (1.17.0)

# %%
# %matplotlib inline
import xarray as xr
import os
from scipy import signal
from netCDF4 import Dataset
from mpl_toolkits.basemap import Basemap
from eofs.standard import Eof
from netCDF4 import num2date
import numpy as np
import numpy.polynomial.polynomial as poly
import netCDF4 as netcdf
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib as mpl
import glob

# %%
# !wget -r -l1 -nd -A "NudA-UVT_ens.micom.hm.20*.nc" -P "/content/drive/MyDrive/NudA-UVT/ocn/" "https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UVT/reana/ocn/"
# Out:
# --2025-10-18 19:20:23--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UVT/reana/ocn/
# Resolving ns9039k.web.sigma2.no (ns9039k.web.sigma2.no)... 158.36.102.245
# Connecting to ns9039k.web.sigma2.no (ns9039k.web.sigma2.no)|158.36.102.245|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/content/drive/MyDrive/NudA-UVT/ocn/index.html.tmp’
#
# index.html.tmp          [  <=>               ]  89.79K   403KB/s    in 0.2s
#
# 2025-10-18 19:20:24 (403 KB/s) - ‘/content/drive/MyDrive/NudA-UVT/ocn/index.html.tmp’ saved [91946]
#
# Loading robots.txt; please ignore errors.
# --2025-10-18 19:20:24--  https://ns9039k.web.sigma2.no/robots.txt
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-10-18 19:20:24 ERROR 404: Not Found.
#
# Removing /content/drive/MyDrive/NudA-UVT/ocn/index.html.tmp since it should be rejected.
#
# --2025-10-18 19:20:24--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UVT/reana/ocn/?C=N;O=D
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/content/drive/MyDrive/NudA-UVT/ocn/index.html?C=N;O=D.tmp’
#
# index.html?C=N;O=D.     [ <=>                ]  89.79K  --.-KB/s    in 0.1s
#
# 2025-10-18 19:20:24 (822 KB/s) - ‘/content/drive/MyDrive/NudA-UVT/ocn/index.html?C=N;O=D.tmp’ saved [91946]
#
# Removing /content/drive/MyDrive/NudA-UVT/ocn/index.html?C=N;O=D.tmp since it should be rejected.
#
# --2025-10-18 19:20:24--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UVT/reana/ocn/?C=M;O=A
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/content/drive/MyDrive/NudA-UVT/ocn/index.html?C=M;O=A.tmp’
#
# index.html?C=M;O=A.     [ <=>                ]  89.79K  --.-KB/s    in 0.008s
#
# 2025-10-18 19:20:24 (10.5 MB/s) - ‘/content/drive/MyDrive/NudA-UVT/ocn/index.html?C=M;O=A.tmp’ saved [91946]
#
# Removing /content/drive/MyDrive/NudA-UVT/ocn/index.html?C=M;O=A.tmp since it should be rejected.
#
# --2025-10-18 19:20:24--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UVT/reana/ocn/?C=S;O=A
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/content/drive/MyDrive/NudA-UVT/ocn/index.html?C=S;O=A.tmp’
#
# index.html?C=S;O=A.     [ <=>                ]  89.79K  --.-KB/s    in 0.01s
#
# 2025-10-18 19:20:25 (9.05 MB/s) - ‘/content/drive/MyDrive/NudA-UVT/ocn/index.html?C=S;O=A.tmp’ saved [91946]
#
# Removing /content/drive/MyDrive/NudA-UVT/ocn/index.html?C=S;O=A.tmp since it should be rejected.
#
# --2025-10-18 19:20:25--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UVT/reana/ocn/?C=D;O=A
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/content/drive/MyDrive/NudA-UVT/ocn/index.html?C=D;O=A.tmp’
#
# index.html?C=D;O=A.     [ <=>                ]  89.79K  --.-KB/s    in 0.01s
#
# 2025-10-18 19:20:25 (7.06 MB/s) - ‘/content/drive/MyDrive/NudA-UVT/ocn/index.html?C=D;O=A.tmp’ saved [91946]
#
# Removing /content/drive/MyDrive/NudA-UVT/ocn/index.html?C=D;O=A.tmp since it should be rejected.
#
# --2025-10-18 19:20:25--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UVT/reana/
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1168 (1.1K) [text/html]
# Saving to: ‘/content/drive/MyDrive/NudA-UVT/ocn/index.html.tmp’
#
# index.html.tmp      100%[===================>]   1.14K  --.-KB/s    in 0s
#
# 2025-10-18 19:20:25 (225 MB/s) - ‘/content/drive/MyDrive/NudA-UVT/ocn/index.html.tmp’ saved [1168/1168]
#
# Removing /content/drive/MyDrive/NudA-UVT/ocn/index.html.tmp since it should be rejected.
#
# --2025-10-18 19:20:25--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UVT/reana/ocn/NudA-UVT_ens.micom.hm.2000-01.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60179068 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UVT/ocn/NudA-UVT_ens.micom.hm.2000-01.nc’
#
# NudA-UVT_ens.micom. 100%[===================>]  57.39M  12.5MB/s    in 4.6s
#
# 2025-10-18 19:20:30 (12.4 MB/s) - ‘/content/drive/MyDrive/NudA-UVT/ocn/NudA-UVT_ens.micom.hm.2000-01.nc’ saved [60179068/60179068]
#
# --2025-10-18 19:20:30--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UVT/reana/ocn/NudA-UVT_ens.micom.hm.2000-02.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60173690 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UVT/ocn/NudA-UVT_ens.micom.hm.2000-02.nc’
#
# NudA-UVT_ens.micom. 100%[===================>]  57.39M  16.1MB/s    in 3.6s
#
# 2025-10-18 19:20:34 (16.1 MB/s) - ‘/content/drive/MyDrive/NudA-UVT/ocn/NudA-UVT_ens.micom.hm.2000-02.nc’ saved [60173690/60173690]
#
# --2025-10-18 19:20:34--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UVT/reana/ocn/NudA-UVT_ens.micom.hm.2000-03.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60174631 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UVT/ocn/NudA-UVT_ens.micom.hm.2000-03.nc’
#
# NudA-UVT_ens.micom. 100%[===================>]  57.39M
MB/s) - ‘/content/drive/MyDrive/NudA-UVT/ocn/NudA-UVT_ens.micom.hm.2010-08.nc’ saved [60170330/60170330]
#
# --2025-10-18 19:32:35--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UVT/reana/ocn/NudA-UVT_ens.micom.hm.2010-09.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60152794 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UVT/ocn/NudA-UVT_ens.micom.hm.2010-09.nc’
#
# NudA-UVT_ens.micom. 100%[===================>]  57.37M  7.81MB/s    in 6.7s
#
# 2025-10-18 19:32:42 (8.61 MB/s) - ‘/content/drive/MyDrive/NudA-UVT/ocn/NudA-UVT_ens.micom.hm.2010-09.nc’ saved [60152794/60152794]
#
# --2025-10-18 19:32:42--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UVT/reana/ocn/NudA-UVT_ens.micom.hm.2010-10.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60138112 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UVT/ocn/NudA-UVT_ens.micom.hm.2010-10.nc’
#
# NudA-UVT_ens.micom. 100%[===================>]  57.35M  8.40MB/s    in 6.6s
#
# 2025-10-18 19:32:49 (8.64 MB/s) - ‘/content/drive/MyDrive/NudA-UVT/ocn/NudA-UVT_ens.micom.hm.2010-10.nc’ saved [60138112/60138112]
#
# --2025-10-18 19:32:49--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UVT/reana/ocn/NudA-UVT_ens.micom.hm.2010-11.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60133417 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UVT/ocn/NudA-UVT_ens.micom.hm.2010-11.nc’
#
# NudA-UVT_ens.micom. 100%[===================>]  57.35M  6.49MB/s    in 7.1s
#
# 2025-10-18 19:32:56 (8.03 MB/s) - ‘/content/drive/MyDrive/NudA-UVT/ocn/NudA-UVT_ens.micom.hm.2010-11.nc’ saved [60133417/60133417]
#
# --2025-10-18 19:32:56--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UVT/reana/ocn/NudA-UVT_ens.micom.hm.2010-12.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60156748 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UVT/ocn/NudA-UVT_ens.micom.hm.2010-12.nc’
#
# NudA-UVT_ens.micom. 100%[===================>]  57.37M  8.92MB/s    in 6.5s
#
# 2025-10-18 19:33:03 (8.85 MB/s) - ‘/content/drive/MyDrive/NudA-UVT/ocn/NudA-UVT_ens.micom.hm.2010-12.nc’ saved [60156748/60156748]
#
# FINISHED --2025-10-18 19:33:03--
# Total wall clock time: 12m 40s
# Downloaded: 138 files, 7.4G in 11m 47s (10.7 MB/s)

# %%
# !wget -P "/content/drive/MyDrive/NudA-UVT/ocn/" "https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UVT/reana/ocn/NudA-UVT_ens.micom.hm.1980-*.nc"
# Out:
# Warning: wildcards not supported in HTTP.
# --2025-10-18 18:34:58--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UVT/reana/ocn/NudA-UVT_ens.micom.hm.1980-*.nc
# Resolving ns9039k.web.sigma2.no (ns9039k.web.sigma2.no)... 158.36.102.245
# Connecting to ns9039k.web.sigma2.no (ns9039k.web.sigma2.no)|158.36.102.245|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-10-18 18:34:59 ERROR 404: Not Found.

# %%
#!apt-get install -y wget

 #Download all .nc files from the folder
# !wget -r -np -nH --cut-dirs=5 -A "*NudA-UVT_ens.micom.hm.1980-05.nc	" \
    -P /content/drive/MyDrive/NudA-UVT/ocn \
https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UVT/reana/ocn/
# Out:
# --2025-10-18 18:35:37--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UVT/reana/ocn/
# Resolving ns9039k.web.sigma2.no (ns9039k.web.sigma2.no)... 158.36.102.245
# Connecting to ns9039k.web.sigma2.no (ns9039k.web.sigma2.no)|158.36.102.245|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html.tmp’
#
# ocn/index.html.tmp      [  <=>               ]  89.79K   373KB/s    in 0.2s
#
# 2025-10-18 18:35:38 (373 KB/s) - ‘/content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html.tmp’ saved [91946]
#
# Loading robots.txt; please ignore errors.
# --2025-10-18 18:35:38--  https://ns9039k.web.sigma2.no/robots.txt
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-10-18 18:35:38 ERROR 404: Not Found.
#
# Removing /content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html.tmp since it should be rejected.
#
# --2025-10-18 18:35:38--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UVT/reana/ocn/?C=N;O=D
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html?C=N;O=D.tmp’
#
# ocn/index.html?C=N;     [   <=>              ]  89.79K   200KB/s    in 0.4s
#
# 2025-10-18 18:35:39 (200 KB/s) - ‘/content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html?C=N;O=D.tmp’ saved [91946]
#
# Removing /content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html?C=N;O=D.tmp since it should be rejected.
#
# --2025-10-18 18:35:39--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UVT/reana/ocn/?C=M;O=A
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html?C=M;O=A.tmp’
#
# ocn/index.html?C=M;     [  <=>               ]  89.79K   267KB/s    in 0.3s
#
# 2025-10-18 18:35:39 (267 KB/s) - ‘/content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html?C=M;O=A.tmp’ saved [91946]
#
# Removing /content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html?C=M;O=A.tmp since it should be rejected.
#
# --2025-10-18 18:35:39--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UVT/reana/ocn/?C=S;O=A
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html?C=S;O=A.tmp’
#
# ocn/index.html?C=S;     [  <=>               ]  89.79K   267KB/s    in 0.3s
#
# 2025-10-18 18:35:40 (267 KB/s) - ‘/content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html?C=S;O=A.tmp’ saved [91946]
#
# Removing /content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html?C=S;O=A.tmp since it should be rejected.
#
# --2025-10-18 18:35:40--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UVT/reana/ocn/?C=D;O=A
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html?C=D;O=A.tmp’
#
# ocn/index.html?C=D;     [  <=>               ]  89.79K   402KB/s    in 0.2s
#
# 2025-10-18 18:35:40 (402 KB/s) - ‘/content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html?C=D;O=A.tmp’ saved [91946]
#
# Removing /content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html?C=D;O=A.tmp since it should be rejected.
#
# --2025-10-18 18:35:40--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UVT/reana/ocn/?C=N;O=A
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html?C=N;O=A.tmp’
#
# ocn/index.html?C=N;     [  <=>               ]  89.79K   402KB/s    in 0.2s
#
# 2025-10-18 18:35:41 (402 KB/s) - ‘/content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html?C=N;O=A.tmp’ saved [91946]
#
# Removing /content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html?C=N;O=A.tmp since it should be rejected.
#
# --2025-10-18 18:35:41--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UVT/reana/ocn/?C=M;O=D
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html?C=M;O=D.tmp’
#
# ocn/index.html?C=M;     [  <=>               ]  89.79K   394KB/s    in 0.2s
#
# 2025-10-18 18:35:41 (394 KB/s) - ‘/content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html?C=M;O=D.tmp’ saved [91946]
#
# Removing /content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html?C=M;O=D.tmp since it should be rejected.
#
# --2025-10-18 18:35:41--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UVT/reana/ocn/?C=S;O=D
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html?C=S;O=D.tmp’
#
# ocn/index.html?C=S;     [  <=>               ]  89.79K   405KB/s    in 0.2s
#
# 2025-10-18 18:35:41 (405 KB/s) - ‘/content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html?C=S;O=D.tmp’ saved [91946]
#
# Removing /content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html?C=S;O=D.tmp since it should be rejected.
#
# --2025-10-18 18:35:41--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UVT/reana/ocn/?C=D;O=D
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html?C=D;O=D.tmp’
#
# ocn/index.html?C=D;     [ <=>                ]  89.79K  --.-KB/s    in 0.1s
#
# 2025-10-18 18:35:42 (777 KB/s) - ‘/content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html?C=D;O=D.tmp’ saved [91946]
#
# Removing /content/drive/MyDrive/NudA-UVT/ocn/ocn/index.html?C=D;O=D.tmp since it should be rejected.
#
# FINISHED --2025-10-18 18:35:42--
# Total wall clock time: 4.8s
# Downloaded: 9 files, 808K in 2.4s (340 KB/s)

# %%
all_files = sorted(glob.glob("/content/drive/MyDrive/NudA-UVT/ocn/NudA-UVT_ens.micom.hm.*.nc"))
files = [f for f in all_files if int(f.split('.')[-2].replace('-', '')) <= 201012]
# Use netCDF4 engine explicitly
ds_all = xr.open_mfdataset(files, combine="by_coords", engine="netcdf4")
sst = ds_all['sst']
print(sst.shape)
# Out:
# /tmp/ipython-input-3351093182.py:4: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   ds_all = xr.open_mfdataset(files, combine="by_coords", engine="netcdf4")
# (372, 384, 320)

# %%
# Extract the time values (cftime objects)
time_vals = ds_all['time'].values

# Get min and max years
year1 = min(t.year for t in time_vals)
year2 = max(t.year for t in time_vals)

print("Year range:", year1, "-", year2)
# Out:
# Year range: 1980 - 2010

# %%
sst_data = sst.values
nt,nlat,nlon = sst.shape
startY = year1
endY   = year2
ndy    = year2-year1+1
ny = nt/ndy
print(startY, endY, ndy, ny)
# Out:
# 1980 2010 31 12.0

# %%
import numpy as np
import numpy.polynomial.polynomial as poly

# Dimensions
nt, nlat, nlon = sst_data.shape

sst_detrend = np.empty(sst_data.shape)
sst_coeffs  = np.empty((2, nlat, nlon))
sst_detrend[:,:,:] = np.nan

x = np.linspace(1, nt, nt)

for i in range(nlat):
    for j in range(nlon):
        y = sst_data[:, i, j]   # <-- use raw numpy array
        if np.all(np.isnan(y)):
            continue
        b = ~np.isnan(y)
        coefs = poly.polyfit(x[b], y[b], 1)
        sst_coeffs[0, i, j] = coefs[0]
        sst_coeffs[1, i, j] = coefs[1]
        ffit = poly.polyval(x[b], coefs)
        sst_detrend[b, i, j] = y[b] - ffit

# %%
sst_all = sst_detrend.reshape((ndy,int(ny),nlat,nlon), order='F').transpose((1,0,2,3)) # year, 36, lat, lon
sst_season = np.mean(sst_all, axis=0)
sst_diff = sst_all - sst_season
#mask_4d = np.broadcast_to((pmask_trimmed==0), sst_all.shape)
#sst_diff = np.ma.masked_array(sst_diff, mask=mask_4d) # have to do this, or fill in zeros in sst_diff.
sst_final = sst_diff.transpose((1,0,2,3)).reshape((ndy*int(ny),nlat,nlon), order='F')

# %%
lat = np.linspace(-90, 90, nlat)  # if first row is South
lon = np.linspace(-180, 180, nlon)

# %%
coslat = np.cos(np.deg2rad(lat))
wgts = np.sqrt(coslat)[..., np.newaxis]
solver = Eof(sst_final, weights=wgts)

print(coslat.shape)
print(wgts.shape)
# Out:
# (384,)
# (384, 1)

# %%
eof1 = solver.eofs(neofs=10)
pc1  = solver.pcs(npcs=10, pcscaling=0)
varfrac = solver.varianceFraction()
lambdas = solver.eigenvalues()

# %%
parallels = np.arange(-90,90,30.)
meridians = np.arange(-180,180,30)

for i in range(0,5):
    fig = plt.figure(figsize=(9,9))
    plt.subplot(211)

    m = Basemap(projection='cyl', llcrnrlon=min(lon), llcrnrlat=min(lat), urcrnrlon=max(lon), urcrnrlat=max(lat))
    x, y = m(*np.meshgrid(lon, lat))
    field = eof1[i, :, :].squeeze()

    # Remove NaNs before finding min/max
    valid = np.isfinite(field)
    vmin = field[valid].min()
    vmax = field[valid].max()

    clevs = np.linspace(vmin, vmax, 21)
    cs = m.contourf(x, y, field, clevs, cmap=plt.cm.RdBu_r)
    #m.drawcoastlines()
    m.drawparallels(parallels, labels=[1,0,0,0])
    m.drawmeridians(meridians, labels=[1,0,0,1])

    cb = m.colorbar(cs, 'right', size='5%', pad='2%')
    cb.set_label('EOF', fontsize=12)
    plt.title('EOF ' + str(i+1), fontsize=16)

    plt.subplot(212)
    #days = np.linspace(year1,year2,int(nt))
    days = np.linspace(year1, year2, int(nt))
    plt.plot(days, pc1[:,i], linewidth=2)
    plt.axhline(0, color='k')
    plt.xlabel('Year')
    plt.ylabel('PC Amplitude')
    plt.ylim(np.min(pc1.squeeze()), np.max(pc1.squeeze()))

    #plt.savefig('EOF' + str(i+1)+'.png')
    #plt.savefig('EOF' + str(i+1)+'.pdf')

# %%
plt.figure(figsize=(11,6))
eof_num = range(1, 11)
plt.plot(eof_num, varfrac[0:10], linewidth=2)
plt.plot(eof_num, varfrac[0:10], linestyle='None', marker="o", color='r', markersize=8)
plt.axhline(0, color='k')
plt.xticks(range(1, 11))
plt.title('Fraction of the total variance represented by each EOF')
plt.xlabel('EOF #')
plt.ylabel('Variance Fraction')
plt.xlim(1, 11)
plt.ylim(np.min(varfrac), np.max(varfrac)+0.01)
#plt.savefig('ScreePlot-Explained-Variance.png')
#plt.savefig('ScreePlot-Explained-Variance.pdf')
# Out:
# (2.620961577837723e-33, 0.7880328554174332)

# %%
sum = 0
for i in range(0, 5):
    sum = sum + round(varfrac[i]*100)
    print("EOF", i, "explain", round(varfrac[i]*100), "%",", variance Cumulée :", sum, "%")
# Out:
# EOF 0 explain 82 % , variance Cumulée : 82 %
# EOF 1 explain 6 % , variance Cumulée : 88 %
# EOF 2 explain 4 % , variance Cumulée : 92 %
# EOF 3 explain 3 % , variance Cumulée : 95 %
# EOF 4 explain 1 % , variance Cumulée : 96 %
