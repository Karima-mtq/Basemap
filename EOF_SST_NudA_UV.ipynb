# %% [markdown]
# <a href="https://colab.research.google.com/github/Karima-mtq/Basemap/blob/main/EOF_SST_NudA_UV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install netCDF4
# !pip install eofs
# !pip install Basemap
# Out:
# Requirement already satisfied: netCDF4 in /usr/local/lib/python3.12/dist-packages (1.7.3)
# Requirement already satisfied: cftime in /usr/local/lib/python3.12/dist-packages (from netCDF4) (1.6.5)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from netCDF4) (2025.10.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from netCDF4) (2.0.2)
# Requirement already satisfied: eofs in /usr/local/lib/python3.12/dist-packages (2.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from eofs) (2.0.2)
# Requirement already satisfied: Basemap in /usr/local/lib/python3.12/dist-packages (2.0.0)
# Requirement already satisfied: basemap_data<3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from Basemap) (2.0.0)
# Requirement already satisfied: packaging<26.0,>=20.5 in /usr/local/lib/python3.12/dist-packages (from Basemap) (25.0)
# Requirement already satisfied: numpy<2.4,>=2.0 in /usr/local/lib/python3.12/dist-packages (from Basemap) (2.0.2)
# Requirement already satisfied: matplotlib<3.11,>=3.4 in /usr/local/lib/python3.12/dist-packages (from Basemap) (3.10.0)
# Requirement already satisfied: pyproj<3.8,>=3.0 in /usr/local/lib/python3.12/dist-packages (from Basemap) (3.7.2)
# Requirement already satisfied: pyshp<2.4,>=2.0 in /usr/local/lib/python3.12/dist-packages (from Basemap) (2.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.4->Basemap) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.4->Basemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.4->Basemap) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.4->Basemap) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.4->Basemap) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.4->Basemap) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.4->Basemap) (2.9.0.post0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyproj<3.8,>=3.0->Basemap) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib<3.11,>=3.4->Basemap) (1.17.0)

# %%
# %matplotlib inline
import xarray as xr
import os
from scipy import signal
from netCDF4 import Dataset
from mpl_toolkits.basemap import Basemap
from eofs.standard import Eof
from netCDF4 import num2date
import numpy as np
import numpy.polynomial.polynomial as poly
import netCDF4 as netcdf
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib as mpl
import glob

# %%
# !wget -r -l1 -nd -A "NudA-UV_ens.micom.hm.*.nc" -P "/content/drive/MyDrive/NudA-UV/ocn/" "https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/"
# Out:
# --2025-10-18 19:40:22--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/
# Resolving ns9039k.web.sigma2.no (ns9039k.web.sigma2.no)... 158.36.102.245
# Connecting to ns9039k.web.sigma2.no (ns9039k.web.sigma2.no)|158.36.102.245|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/index.html.tmp’
#
# index.html.tmp          [   <=>              ]  89.06K   154KB/s    in 0.6s
#
# 2025-10-18 19:40:23 (154 KB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/index.html.tmp’ saved [91199]
#
# Loading robots.txt; please ignore errors.
# --2025-10-18 19:40:23--  https://ns9039k.web.sigma2.no/robots.txt
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-10-18 19:40:23 ERROR 404: Not Found.
#
# Removing /content/drive/MyDrive/NudA-UV/ocn/index.html.tmp since it should be rejected.
#
# --2025-10-18 19:40:23--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/?C=N;O=D
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/index.html?C=N;O=D.tmp’
#
# index.html?C=N;O=D.     [   <=>              ]  89.06K   198KB/s    in 0.5s
#
# 2025-10-18 19:40:24 (198 KB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/index.html?C=N;O=D.tmp’ saved [91199]
#
# Removing /content/drive/MyDrive/NudA-UV/ocn/index.html?C=N;O=D.tmp since it should be rejected.
#
# --2025-10-18 19:40:24--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/?C=M;O=A
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/index.html?C=M;O=A.tmp’
#
# index.html?C=M;O=A.     [  <=>               ]  89.06K   263KB/s    in 0.3s
#
# 2025-10-18 19:40:24 (263 KB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/index.html?C=M;O=A.tmp’ saved [91199]
#
# Removing /content/drive/MyDrive/NudA-UV/ocn/index.html?C=M;O=A.tmp since it should be rejected.
#
# --2025-10-18 19:40:24--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/?C=S;O=A
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/index.html?C=S;O=A.tmp’
#
# index.html?C=S;O=A.     [  <=>               ]  89.06K   265KB/s    in 0.3s
#
# 2025-10-18 19:40:25 (265 KB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/index.html?C=S;O=A.tmp’ saved [91199]
#
# Removing /content/drive/MyDrive/NudA-UV/ocn/index.html?C=S;O=A.tmp since it should be rejected.
#
# --2025-10-18 19:40:25--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/?C=D;O=A
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/index.html?C=D;O=A.tmp’
#
# index.html?C=D;O=A.     [  <=>               ]  89.06K   389KB/s    in 0.2s
#
# 2025-10-18 19:40:25 (389 KB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/index.html?C=D;O=A.tmp’ saved [91199]
#
# Removing /content/drive/MyDrive/NudA-UV/ocn/index.html?C=D;O=A.tmp since it should be rejected.
#
# --2025-10-18 19:40:25--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1165 (1.1K) [text/html]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/index.html.tmp’
#
# index.html.tmp      100%[===================>]   1.14K  --.-KB/s    in 0s
#
# 2025-10-18 19:40:25 (181 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/index.html.tmp’ saved [1165/1165]
#
# Removing /content/drive/MyDrive/NudA-UV/ocn/index.html.tmp since it should be rejected.
#
# --2025-10-18 19:40:25--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1980-01.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59999511 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1980-01.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.22M  12.8MB/s    in 10s
#
# 2025-10-18 19:40:36 (5.49 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1980-01.nc’ saved [59999511/59999511]
#
# --2025-10-18 19:40:36--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1980-02.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60002628 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1980-02.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.22M  12.1MB/s    in 4.7s
#
# 2025-10-18 19:40:41 (12.3 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1980-02.nc’ saved [60002628/60002628]
#
# --2025-10-18 19:40:41--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1980-03.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60004756 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1980-03.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.22M  7.30MB/s    in 6.7s
#
# 2025-10-18 19:40:49 (8.59 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1980-03.nc’ saved [60004756/60004756]
#
# --2025-10-18 19:40:49--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1980-04.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60017302 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1980-04.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.24M  8.02MB/s    in 6.5s
#
# 2025-10-18 19:40:56 (8.78 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1980-04.nc’ saved [60017302/60017302]
#
# --2025-10-18 19:40:56--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1980-05.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60029694 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1980-05.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.25M  8.88MB/s    in 6.4s
#
# 2025-10-18 19:41:02 (8.94 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1980-05.nc’ saved [60029694/60029694]
#
# --2025-10-18 19:41:02--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1980-06.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60045300 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1980-06.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.26M  8.46MB/s    in 6.1s
#
# 2025-10-18 19:41:09 (9.32 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1980-06.nc’ saved [60045300/60045300]
#
# --2025-10-18 19:41:09--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1980-07.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60067250 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1980-07.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.28M  12.3MB/s    in 5.0s
#
# 2025-10-18 19:41:15 (11.5 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1980-07.nc’ saved [60067250/60067250]
#
# --2025-10-18 19:41:15--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1980-08.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60091882 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1980-08.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.31M  7.20MB/s    in 6.8s
#
# 2025-10-18 19:41:22 (8.42 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1980-08.nc’ saved [60091882/60091882]
#
# --2025-10-18 19:41:22--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1980-09.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60087770 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1980-09.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.30M  10.1MB/s    in 9.9s
#
# 2025-10-18 19:41:32 (5.79 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1980-09.nc’ saved [60087770/60087770]
#
# --2025-10-18 19:41:32--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1980-10.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60065244 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1980-10.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.28M  8.50MB/s    in 5.9s
#
# 2025-10-18 19:41:38 (9.70 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1980-10.nc’ saved [60065244/60065244]
#
# --2025-10-18 19:41:39--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1980-11.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60045922 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1980-11.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.26M  7.52MB/s    in 7.2s
#
# 2025-10-18 19:41:46 (8.01 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1980-11.nc’ saved [60045922/60045922]
#
# --2025-10-18 19:41:46--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1980-12.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60061897 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1980-12.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.28M  8.59MB/s    in 6.3s
#
# 2025-10-18 19:41:52 (9.04 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1980-12.nc’ saved [60061897/60061897]
#
# --2025-10-18 19:41:52--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1981-01.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60084650 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1981-01.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.30M  8.14MB/s    in 6.6s
#
# 2025-10-18 19:41:59 (8.66 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1981-01.nc’ saved [60084650/60084650]
#
# --2025-10-18 19:41:59--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1981-02.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60111429 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1981-02.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.33M  4.77MB/s    in 9.0s
#
# 2025-10-18 19:42:08 (6.35 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1981-02.nc’ saved [60111429/60111429]
#
# --2025-10-18 19:42:08--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1981-03.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60106191 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1981-03.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.32M  8.60MB/s    in 6.4s
#
# 2025-10-18 19:42:15 (8.90 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1981-03.nc’ saved [60106191/60106191]
#
# --2025-10-18 19:42:15--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1981-04.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60093096 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1981-04.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.31M  8.67MB/s    in 6.4s
#
# 2025-10-18 19:42:22 (9.01 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1981-04.nc’ saved [60093096/60093096]
#
# --2025-10-18 19:42:22--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1981-05.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60095472 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1981-05.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.31M  7.88MB/s    in 6.9s
#
# 2025-10-18 19:42:29 (8.31 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1981-05.nc’ saved [60095472/60095472]
#
# --2025-10-18 19:42:29--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1981-06.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60098745 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1981-06.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.31M  7.93MB/s    in 7.0s
#
# 2025-10-18 19:42:36 (8.16 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1981-06.nc’ saved [60098745/60098745]
#
# --2025-10-18 19:42:36--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1981-07.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60099305 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1981-07.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.31M  8.21MB/s    in 6.7s
#
# 2025-10-18 19:42:43 (8.60 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1981-07.nc’ saved [60099305/60099305]
#
# --2025-10-18 19:42:43--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1981-08.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60109720 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1981-08.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.32M  8.14MB/s    in 6.9s
#
# 2025-10-18 19:42:50 (8.37 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1981-08.nc’ saved [60109720/60109720]
#
# --2025-10-18 19:42:50--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1981-09.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60107705 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1981-09.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.32M  8.48MB/s    in 6.2s
#
# 2025-10-18 19:42:56 (9.19 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1981-09.nc’ saved [60107705/60107705]
#
# --2025-10-18 19:42:56--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1981-10.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60103497 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1981-10.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.32M  9.81MB/s    in 5.8s
#
# 2025-10-18 19:43:03 (9.90 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1981-10.nc’ saved [60103497/60103497]
#
# --2025-10-18 19:43:03--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1981-11.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60098381 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1981-11.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.31M  7.46MB/s    in 7.3s
#
# 2025-10-18 19:43:10 (7.89 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1981-11.nc’ saved [60098381/60098381]
#
# --2025-10-18 19:43:10--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1981-12.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60094755 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1981-12.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.31M  7.73MB/s    in 6.8s
#
# 2025-10-18 19:43:17 (8.49 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1981-12.nc’ saved [60094755/60094755]
#
# --2025-10-18 19:43:17--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1982-01.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60116028 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1982-01.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.33M  8.81MB/s    in 6.7s
#
# 2025-10-18 19:43:24 (8.57 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1982-01.nc’ saved [60116028/60116028]
#
# --2025-10-18 19:43:24--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1982-02.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60129985 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1982-02.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.34M  6.32MB/s    in 6.9s
#
# 2025-10-18 19:43:31 (8.29 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1982-02.nc’ saved [60129985/60129985]
#
# --2025-10-18 19:43:31--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1982-03.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60110709 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1982-03.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.33M  9.88MB/s    in 7.6s
#
# 2025-10-18 19:43:39 (7.50 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1982-03.nc’ saved [60110709/60110709]
#
# --2025-10-18 19:43:39--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1982-04.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60122938 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1982-04.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.34M  7.58MB/s    in 6.5s
#
# 2025-10-18 19:43:46 (8.81 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1982-04.nc’ saved [60122938/60122938]
#
# --2025-10-18 19:43:46--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1982-05.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60122166 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1982-05.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.34M  8.10MB/s    in 6.5s
#
# 2025-10-18 19:43:52 (8.83 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1982-05.nc’ saved [60122166/60122166]
#
# --2025-10-18 19:43:52--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1982-06.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60124061 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1982-06.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.34M  6.29MB/s    in 8.0s
#
# 2025-10-18 19:44:01 (7.17 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1982-06.nc’ saved [60124061/60124061]
#
# --2025-10-18 19:44:01--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1982-07.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60145205 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1982-07.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.36M  7.92MB/s    in 7.0s
#
# 2025-10-18 19:44:08 (8.17 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1982-07.nc’ saved [60145205/60145205]
#
# --2025-10-18 19:44:08--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1982-08.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60157773 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1982-08.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.37M  5.92MB/s    in 8.3s
#
# 2025-10-18 19:44:16 (6.90 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1982-08.nc’ saved [60157773/60157773]
#
# --2025-10-18 19:44:16--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1982-09.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60169034 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1982-09.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.38M  8.38MB/s    in 6.8s
#
# 2025-10-18 19:44:23 (8.38 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1982-09.nc’ saved [60169034/60169034]
#
# --2025-10-18 19:44:23--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1982-10.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60158960 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1982-10.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.37M  7.72MB/s    in 6.7s
#
# 2025-10-18 19:44:30 (8.54 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1982-10.nc’ saved [60158960/60158960]
#
# --2025-10-18 19:44:30--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1982-11.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60148095 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1982-11.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.36M  13.0MB/s    in 4.6s
#
# 2025-10-18 19:44:35 (12.5 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1982-11.nc’ saved [60148095/60148095]
#
# --2025-10-18 19:44:35--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1982-12.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60152475 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1982-12.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.37M  9.51MB/s    in 6.5s
#
# 2025-10-18 19:44:42 (8.81 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1982-12.nc’ saved [60152475/60152475]
#
# --2025-10-18 19:44:42--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1983-01.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60187134 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1983-01.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.40M  8.42MB/s    in 6.4s
#
# 2025-10-18 19:44:48 (8.92 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1983-01.nc’ saved [60187134/60187134]
#
# --2025-10-18 19:44:49--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1983-02.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60198719 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1983-02.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.41M  7.91MB/s    in 7.0s
#
# 2025-10-18 19:44:56 (8.23 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1983-02.nc’ saved [60198719/60198719]
#
# --2025-10-18 19:44:56--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1983-03.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60192941 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1983-03.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.40M  8.34MB/s    in 6.2s
#
# 2025-10-18 19:45:02 (9.20 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1983-03.nc’ saved [60192941/60192941]
#
# --2025-10-18 19:45:02--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1983-04.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60177282 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1983-04.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.39M  9.80MB/s    in 5.8s
#
# 2025-10-18 19:45:09 (9.95 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1983-04.nc’ saved [60177282/60177282]
#
# --2025-10-18 19:45:09--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1983-05.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60166831 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1983-05.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.38M  16.5MB/s    in 3.8s
#
# 2025-10-18 19:45:13 (14.9 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1983-05.nc’ saved [60166831/60166831]
#
# --2025-10-18 19:45:13--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1983-06.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60181934 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1983-06.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.39M  8.80MB/s    in 6.5s
#
# 2025-10-18 19:45:20 (8.86 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1983-06.nc’ saved [60181934/60181934]
#
# --2025-10-18 19:45:20--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1983-07.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60177940 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1983-07.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.39M  8.11MB/s    in 6.6s
#
# 2025-10-18 19:45:26 (8.69 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1983-07.nc’ saved [60177940/60177940]
#
# --2025-10-18 19:45:26--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1983-08.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60188101 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1983-08.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.40M  9.78MB/s    in 5.8s
#
# 2025-10-18 19:45:33 (9.96 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1983-08.nc’ saved [60188101/60188101]
#
# --2025-10-18 19:45:33--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1983-09.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60185688 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1983-09.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.40M  11.8MB/s    in 5.2s
#
# 2025-10-18 19:45:39 (11.0 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1983-09.nc’ saved [60185688/60185688]
#
# --2025-10-18 19:45:39--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1983-10.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60160587 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1983-10.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.37M  7.18MB/s    in 8.6s
#
# 2025-10-18 19:45:48 (6.69 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1983-10.nc’ saved [60160587/60160587]
#
# --2025-10-18 19:45:48--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1983-11.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60148081 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1983-11.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.36M  8.54MB/s    in 6.5s
#
# 2025-10-18 19:45:55 (8.80 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1983-11.nc’ saved [60148081/60148081]
#
# --2025-10-18 19:45:55--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1983-12.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60162349 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1983-12.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.38M  6.32MB/s    in 7.2s
#
# 2025-10-18 19:46:02 (7.99 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1983-12.nc’ saved [60162349/60162349]
#
# --2025-10-18 19:46:02--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1984-01.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60179855 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1984-01.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.39M  15.6MB/s    in 3.9s
#
# 2025-10-18 19:46:06 (14.7 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1984-01.nc’ saved [60179855/60179855]
#
# --2025-10-18 19:46:06--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1984-02.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60197488 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1984-02.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.41M  8.57MB/s    in 6.9s
#
# 2025-10-18 19:46:13 (8.38 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1984-02.nc’ saved [60197488/60197488]
#
# --2025-10-18 19:46:13--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1984-03.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60183286 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1984-03.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.39M  9.15MB/s    in 9.1s
#
# 2025-10-18 19:46:22 (6.33 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1984-03.nc’ saved [60183286/60183286]
#
# --2025-10-18 19:46:22--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1984-04.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60165134 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1984-04.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.38M  11.7MB/s    in 5.1s
#
# 2025-10-18 19:46:29 (11.2 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1984-04.nc’ saved [60165134/60165134]
#
# --2025-10-18 19:46:29--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1984-05.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60168705 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1984-05.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.38M  13.5MB/s    in 4.8s
#
# 2025-10-18 19:46:34 (12.1 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1984-05.nc’ saved [60168705/60168705]
#
# --2025-10-18 19:46:34--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1984-06.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60179242 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1984-06.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.39M  12.2MB/s    in 4.8s
#
# 2025-10-18 19:46:40 (12.0 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1984-06.nc’ saved [60179242/60179242]
#
# --2025-10-18 19:46:40--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1984-07.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60198412 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1984-07.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.41M  7.96MB/s    in 8.0s
#
# 2025-10-18 19:46:48 (7.22 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1984-07.nc’ saved [60198412/60198412]
#
# --2025-10-18 19:46:48--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1984-08.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60202151 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1984-08.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.41M  8.65MB/s    in 6.3s
#
# 2025-10-18 19:46:55 (9.11 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1984-08.nc’ saved [60202151/60202151]
#
# --2025-10-18 19:46:55--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1984-09.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60192595 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1984-09.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.40M  11.7MB/s    in 5.1s
#
# 2025-10-18 19:47:01 (11.2 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1984-09.nc’ saved [60192595/60192595]
#
# --2025-10-18 19:47:01--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1984-10.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60169782 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1984-10.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.38M  15.4MB/s    in 4.1s
#
# 2025-10-18 19:47:06 (13.9 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1984-10.nc’ saved [60169782/60169782]
#
# --2025-10-18 19:47:06--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1984-11.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60161723 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1984-11.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.37M  8.73MB/s    in 7.0s
#
# 2025-10-18 19:47:13 (8.24 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1984-11.nc’ saved [60161723/60161723]
#
# --2025-10-18 19:47:13--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1984-12.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60167558 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1984-12.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.38M  7.63MB/s    in 6.9s
#
# 2025-10-18 19:47:20 (8.34 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1984-12.nc’ saved [60167558/60167558]
#
# --2025-10-18 19:47:20--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1985-01.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60177479 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1985-01.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.39M  9.35MB/s    in 5.9s
#
# 2025-10-18 19:47:26 (9.70 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1985-01.nc’ saved [60177479/60177479]
#
# --2025-10-18 19:47:26--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1985-02.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60176542 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1985-02.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.39M  11.4MB/s    in 5.3s
#
# 2025-10-18 19:47:32 (10.8 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1985-02.nc’ saved [60176542/60176542]
#
# --2025-10-18 19:47:33--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1985-03.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60179689 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1985-03.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.39M  7.99MB/s    in 6.3s
#
# 2025-10-18 19:47:39 (9.17 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1985-03.nc’ saved [60179689/60179689]
#
# --2025-10-18 19:47:39--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1985-04.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60162019 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1985-04.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.37M  10.1MB/s    in 5.5s
#
# 2025-10-18 19:47:45 (10.4 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1985-04.nc’ saved [60162019/60162019]
#
# --2025-10-18 19:47:46--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1985-05.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60159146 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1985-05.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.37M  7.57MB/s    in 8.8s
#
# 2025-10-18 19:47:54 (6.54 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1985-05.nc’ saved [60159146/60159146]
#
# --2025-10-18 19:47:54--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1985-06.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60174209 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1985-06.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.39M  12.4MB/s    in 4.8s
#
# 2025-10-18 19:47:59 (12.0 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1985-06.nc’ saved [60174209/60174209]
#
# --2025-10-18 19:47:59--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1985-07.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60190231 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1985-07.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.40M  8.76MB/s    in 6.0s
#
# 2025-10-18 19:48:07 (9.60 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1985-07.nc’ saved [60190231/60190231]
#
# --2025-10-18 19:48:07--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1985-08.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60198632 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1985-08.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.41M  7.78MB/s    in 7.3s
#
# 2025-10-18 19:48:15 (7.90 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1985-08.nc’ saved [60198632/60198632]
#
# --2025-10-18 19:48:15--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1985-09.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60190463 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1985-09.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.40M  4.88MB/s    in 8.6s
#
# 2025-10-18 19:48:24 (6.68 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1985-09.nc’ saved [60190463/60190463]
#
# --2025-10-18 19:48:24--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1985-10.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60185754 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1985-10.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.40M  8.25MB/s    in 6.6s
#
# 2025-10-18 19:48:31 (8.68 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1985-10.nc’ saved [60185754/60185754]
#
# --2025-10-18 19:48:31--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1985-11.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60180507 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1985-11.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.39M  10.0MB/s    in 5.5s
#
# 2025-10-18 19:48:37 (10.4 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1985-11.nc’ saved [60180507/60180507]
#
# --2025-10-18 19:48:37--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1985-12.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60177502 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1985-12.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.39M  10.1MB/s    in 5.6s
#
# 2025-10-18 19:48:43 (10.3 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1985-12.nc’ saved [60177502/60177502]
#
# --2025-10-18 19:48:44--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1986-01.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60180699 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1986-01.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.39M  9.40MB/s    in 6.3s
#
# 2025-10-18 19:48:50 (9.07 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1986-01.nc’ saved [60180699/60180699]
#
# --2025-10-18 19:48:50--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1986-02.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60194280 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1986-02.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.41M  8.62MB/s    in 6.4s
#
# 2025-10-18 19:48:57 (9.03 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1986-02.nc’ saved [60194280/60194280]
#
# --2025-10-18 19:48:57--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1986-03.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60190686 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1986-03.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.40M  8.17MB/s    in 6.8s
#
# 2025-10-18 19:49:04 (8.43 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1986-03.nc’ saved [60190686/60190686]
#
# --2025-10-18 19:49:04--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.1986-04.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60184594 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.1986-04.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.40M  7.82MB/s    in 6.4s
#
# ...
#
# 2025-10-18 20:17:39 (20.4 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2008-09.nc’ saved [60187414/60187414]
#
# --2025-10-18 20:17:39--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2008-10.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60189075 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2008-10.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.40M  13.4MB/s    in 4.3s
#
# 2025-10-18 20:17:43 (13.4 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2008-10.nc’ saved [60189075/60189075]
#
# --2025-10-18 20:17:43--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2008-11.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60171379 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2008-11.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.38M  19.7MB/s    in 2.9s
#
# 2025-10-18 20:17:46 (19.7 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2008-11.nc’ saved [60171379/60171379]
#
# --2025-10-18 20:17:46--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2008-12.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60179800 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2008-12.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.39M  12.8MB/s    in 4.1s
#
# 2025-10-18 20:17:50 (14.2 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2008-12.nc’ saved [60179800/60179800]
#
# --2025-10-18 20:17:50--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2009-01.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60204390 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2009-01.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.42M  21.6MB/s    in 2.7s
#
# 2025-10-18 20:17:53 (21.6 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2009-01.nc’ saved [60204390/60204390]
#
# --2025-10-18 20:17:53--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2009-02.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60208487 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2009-02.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.42M  11.6MB/s    in 4.4s
#
# 2025-10-18 20:17:58 (13.2 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2009-02.nc’ saved [60208487/60208487]
#
# --2025-10-18 20:17:58--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2009-03.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60188275 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2009-03.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.40M  19.6MB/s    in 2.9s
#
# 2025-10-18 20:18:01 (19.6 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2009-03.nc’ saved [60188275/60188275]
#
# --2025-10-18 20:18:01--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2009-04.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60191757 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2009-04.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.40M  13.5MB/s    in 4.0s
#
# 2025-10-18 20:18:05 (14.4 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2009-04.nc’ saved [60191757/60191757]
#
# --2025-10-18 20:18:05--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2009-05.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60187744 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2009-05.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.40M  11.5MB/s    in 5.0s
#
# 2025-10-18 20:18:11 (11.6 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2009-05.nc’ saved [60187744/60187744]
#
# --2025-10-18 20:18:11--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2009-06.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60193992 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2009-06.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.41M  11.9MB/s    in 5.1s
#
# 2025-10-18 20:18:18 (11.2 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2009-06.nc’ saved [60193992/60193992]
#
# --2025-10-18 20:18:18--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2009-07.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60195631 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2009-07.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.41M  11.8MB/s    in 5.5s
#
# 2025-10-18 20:18:24 (10.4 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2009-07.nc’ saved [60195631/60195631]
#
# --2025-10-18 20:18:24--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2009-08.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60198458 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2009-08.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.41M  10.2MB/s    in 5.7s
#
# 2025-10-18 20:18:31 (10.0 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2009-08.nc’ saved [60198458/60198458]
#
# --2025-10-18 20:18:31--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2009-09.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60195501 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2009-09.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.41M  14.2MB/s    in 4.4s
#
# 2025-10-18 20:18:35 (13.1 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2009-09.nc’ saved [60195501/60195501]
#
# --2025-10-18 20:18:35--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2009-10.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60187428 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2009-10.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.40M  15.0MB/s    in 4.8s
#
# 2025-10-18 20:18:40 (12.0 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2009-10.nc’ saved [60187428/60187428]
#
# --2025-10-18 20:18:40--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2009-11.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60176246 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2009-11.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.39M  14.9MB/s    in 3.9s
#
# 2025-10-18 20:18:44 (14.8 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2009-11.nc’ saved [60176246/60176246]
#
# --2025-10-18 20:18:44--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2009-12.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60178043 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2009-12.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.39M  13.5MB/s    in 4.8s
#
# 2025-10-18 20:18:49 (11.9 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2009-12.nc’ saved [60178043/60178043]
#
# --2025-10-18 20:18:49--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2010-01.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60185367 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2010-01.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.40M  12.5MB/s    in 4.6s
#
# 2025-10-18 20:18:54 (12.4 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2010-01.nc’ saved [60185367/60185367]
#
# --2025-10-18 20:18:54--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2010-02.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60189538 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2010-02.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.40M  13.5MB/s    in 4.4s
#
# 2025-10-18 20:19:00 (13.2 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2010-02.nc’ saved [60189538/60189538]
#
# --2025-10-18 20:19:00--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2010-03.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60174974 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2010-03.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.39M  12.2MB/s    in 5.4s
#
# 2025-10-18 20:19:06 (10.7 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2010-03.nc’ saved [60174974/60174974]
#
# --2025-10-18 20:19:06--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2010-04.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60170922 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2010-04.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.38M  13.1MB/s    in 4.4s
#
# 2025-10-18 20:19:10 (13.2 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2010-04.nc’ saved [60170922/60170922]
#
# --2025-10-18 20:19:10--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2010-05.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60168640 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2010-05.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.38M  13.8MB/s    in 5.0s
#
# 2025-10-18 20:19:16 (11.4 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2010-05.nc’ saved [60168640/60168640]
#
# --2025-10-18 20:19:16--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2010-06.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60178562 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2010-06.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.39M  14.4MB/s    in 4.0s
#
# 2025-10-18 20:19:20 (14.4 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2010-06.nc’ saved [60178562/60178562]
#
# --2025-10-18 20:19:20--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2010-07.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60184115 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2010-07.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.40M  12.8MB/s    in 6.0s
#
# 2025-10-18 20:19:26 (9.50 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2010-07.nc’ saved [60184115/60184115]
#
# --2025-10-18 20:19:26--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2010-08.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60186418 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2010-08.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.40M  11.4MB/s    in 4.7s
#
# 2025-10-18 20:19:31 (12.2 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2010-08.nc’ saved [60186418/60186418]
#
# --2025-10-18 20:19:31--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2010-09.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60172849 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2010-09.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.38M  12.4MB/s    in 4.4s
#
# 2025-10-18 20:19:36 (13.0 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2010-09.nc’ saved [60172849/60172849]
#
# --2025-10-18 20:19:36--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2010-10.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60167297 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2010-10.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.38M  13.9MB/s    in 6.8s
#
# 2025-10-18 20:19:43 (8.42 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2010-10.nc’ saved [60167297/60167297]
#
# --2025-10-18 20:19:43--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2010-11.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60165770 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2010-11.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.38M  15.0MB/s    in 3.8s
#
# 2025-10-18 20:19:47 (14.9 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2010-11.nc’ saved [60165770/60165770]
#
# --2025-10-18 20:19:47--  https://ns9039k.web.sigma2.no/datapeak/lgarcia/initializations/NudA-UV/reana/ocn/NudA-UV_ens.micom.hm.2010-12.nc
# Reusing existing connection to ns9039k.web.sigma2.no:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60181384 (57M) [application/x-netcdf]
# Saving to: ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2010-12.nc’
#
# NudA-UV_ens.micom.h 100%[===================>]  57.39M  12.8MB/s    in 5.0s
#
# 2025-10-18 20:19:52 (11.5 MB/s) - ‘/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.2010-12.nc’ saved [60181384/60181384]
#
# FINISHED --2025-10-18 20:19:52--
# Total wall clock time: 39m 30s
# Downloaded: 378 files, 21G in 37m 6s (9.59 MB/s)

# %%
all_files = sorted(glob.glob("/content/drive/MyDrive/NudA-UV/ocn/NudA-UV_ens.micom.hm.*.nc"))
files = [f for f in all_files if int(f.split('.')[-2].replace('-', '')) <= 201012]
# Use netCDF4 engine explicitly
ds_all = xr.open_mfdataset(files, combine="by_coords", engine="netcdf4")
sst = ds_all['sst']
print(sst.shape)
# Out:
# /tmp/ipython-input-1587700148.py:4: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   ds_all = xr.open_mfdataset(files, combine="by_coords", engine="netcdf4")
# (372, 384, 320)

# %%
# Extract the time values (cftime objects)
time_vals = ds_all['time'].values

# Get min and max years
year1 = min(t.year for t in time_vals)
year2 = max(t.year for t in time_vals)

print("Year range:", year1, "-", year2)
# Out:
# Year range: 1980 - 2010

# %%
sst_data = sst.values
nt,nlat,nlon = sst.shape
startY = year1
endY   = year2
ndy    = year2-year1+1
ny = nt/ndy
print(startY, endY, ndy, ny)
# Out:
# 1980 2010 31 12.0

# %%
import numpy as np
import numpy.polynomial.polynomial as poly

# Dimensions
nt, nlat, nlon = sst_data.shape

sst_detrend = np.empty(sst_data.shape)
sst_coeffs  = np.empty((2, nlat, nlon))
sst_detrend[:,:,:] = np.nan

x = np.linspace(1, nt, nt)

for i in range(nlat):
    for j in range(nlon):
        y = sst_data[:, i, j]   # <-- use raw numpy array
        if np.all(np.isnan(y)):
            continue
        b = ~np.isnan(y)
        coefs = poly.polyfit(x[b], y[b], 1)
        sst_coeffs[0, i, j] = coefs[0]
        sst_coeffs[1, i, j] = coefs[1]
        ffit = poly.polyval(x[b], coefs)
        sst_detrend[b, i, j] = y[b] - ffit

# %%
sst_all = sst_detrend.reshape((ndy,int(ny),nlat,nlon), order='F').transpose((1,0,2,3)) # year, 36, lat, lon
sst_season = np.mean(sst_all, axis=0)
sst_diff = sst_all - sst_season
#mask_4d = np.broadcast_to((pmask_trimmed==0), sst_all.shape)
#sst_diff = np.ma.masked_array(sst_diff, mask=mask_4d) # have to do this, or fill in zeros in sst_diff.
sst_final = sst_diff.transpose((1,0,2,3)).reshape((ndy*int(ny),nlat,nlon), order='F')

# %%
lat = np.linspace(-90, 90, nlat)  # if first row is South
lon = np.linspace(-180, 180, nlon)

# %%
coslat = np.cos(np.deg2rad(lat))
wgts = np.sqrt(coslat)[..., np.newaxis]
solver = Eof(sst_final, weights=wgts)

print(coslat.shape)
print(wgts.shape)
# Out:
# (384,)
# (384, 1)

# %%
eof1 = solver.eofs(neofs=10)
pc1  = solver.pcs(npcs=10, pcscaling=0)
varfrac = solver.varianceFraction()
lambdas = solver.eigenvalues()

# %%
parallels = np.arange(-90,90,30.)
meridians = np.arange(-180,180,30)

for i in range(0,5):
    fig = plt.figure(figsize=(9,9))
    plt.subplot(211)

    m = Basemap(projection='cyl', llcrnrlon=min(lon), llcrnrlat=min(lat), urcrnrlon=max(lon), urcrnrlat=max(lat))
    x, y = m(*np.meshgrid(lon, lat))
    field = eof1[i, :, :].squeeze()

    # Remove NaNs before finding min/max
    valid = np.isfinite(field)
    vmin = field[valid].min()
    vmax = field[valid].max()

    clevs = np.linspace(vmin, vmax, 21)
    cs = m.contourf(x, y, field, clevs, cmap=plt.cm.RdBu_r)
    #m.drawcoastlines()
    m.drawparallels(parallels, labels=[1,0,0,0])
    m.drawmeridians(meridians, labels=[1,0,0,1])

    cb = m.colorbar(cs, 'right', size='5%', pad='2%')
    cb.set_label('EOF', fontsize=12)
    plt.title('EOF ' + str(i+1), fontsize=16)

    plt.subplot(212)
    #days = np.linspace(year1,year2,int(nt))
    days = np.linspace(year1, year2, int(nt))
    plt.plot(days, pc1[:,i], linewidth=2)
    plt.axhline(0, color='k')
    plt.xlabel('Year')
    plt.ylabel('PC Amplitude')
    plt.ylim(np.min(pc1.squeeze()), np.max(pc1.squeeze()))

    #plt.savefig('EOF' + str(i+1)+'.png')
    #plt.savefig('EOF' + str(i+1)+'.pdf')

# %%
plt.figure(figsize=(11,6))
eof_num = range(1, 11)
plt.plot(eof_num, varfrac[0:10], linewidth=2)
plt.plot(eof_num, varfrac[0:10], linestyle='None', marker="o", color='r', markersize=8)
plt.axhline(0, color='k')
plt.xticks(range(1, 11))
plt.title('Fraction of the total variance represented by each EOF')
plt.xlabel('EOF #')
plt.ylabel('Variance Fraction')
plt.xlim(1, 11)
plt.ylim(np.min(varfrac), np.max(varfrac)+0.01)
#plt.savefig('ScreePlot-Explained-Variance.png')
#plt.savefig('ScreePlot-Explained-Variance.pdf')
# Out:
# (4.983956235122335e-33, 0.784241002731298)

# %%
sum = 0
for i in range(0, 5):
    sum = sum + round(varfrac[i]*100)
    print("EOF", i, "explain", round(varfrac[i]*100), "%",", variance Cumulée :", sum, "%")
# Out:
# EOF 0 explain 77 % , variance Cumulée : 77 %
# EOF 1 explain 6 % , variance Cumulée : 83 %
# EOF 2 explain 4 % , variance Cumulée : 87 %
# EOF 3 explain 3 % , variance Cumulée : 90 %
# EOF 4 explain 1 % , variance Cumulée : 91 %
